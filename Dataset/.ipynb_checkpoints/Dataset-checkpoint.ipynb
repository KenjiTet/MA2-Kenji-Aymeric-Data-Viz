# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
poster = pd.read_csv('duplicate_free_41K.csv')
poster = poster.drop(['id','action','year','rating', 'adventure','comedy','crime','drama','fantasy','horror','mystery','romance','sci-fi','short','thriller','animation'], axis=1)
poster.rename(columns={"title": "Film"}, inplace=True)

# %%
year_df =  big_actor_movie[['Film','Year']]

# %%
big_actor_movie = pd.read_csv('actorfilms.csv')  
df_big_actor_movie = big_actor_movie[['Film', 'Actor','Year','Rating']]
df_big_actor_movie
# Out:
#                                   Film                Actor  Year  Rating
# 0                          Ghost Story         Fred Astaire  1981     6.3
# 1                      The Purple Taxi         Fred Astaire  1977     6.6
# 2                The Amazing Dobermans         Fred Astaire  1976     5.3
# 3                 The Towering Inferno         Fred Astaire  1974     7.0
# 4                            Midas Run         Fred Astaire  1969     4.8
# ...                                ...                  ...   ...     ...
# 191868                     Jojo Rabbit  Roman Griffin Davis  2019     7.9
# 191869                       Silk Road            Lexi Rabe  2021     5.9
# 191870               Avengers: Endgame            Lexi Rabe  2019     8.4
# 191871  Godzilla: King of the Monsters            Lexi Rabe  2019     6.0
# 191872                   Wander Darkly      Inde Navarrette  2020     5.8
#
# [191873 rows x 4 columns]

# %%
big_actors = np.unique(df_big_actor_movie['Actor'])
big_films = np.unique(df_big_actor_movie['Film'])


big_actor_by_film = dict.fromkeys(big_films, [])
big_actor_by_film

for i in range(len(df_big_actor_movie)):
    big_actor_by_film[df_big_actor_movie['Film'][i]] = big_actor_by_film[df_big_actor_movie['Film'][i]] + [df_big_actor_movie['Actor'][i]]

# %%
big_actor_by_film_df = pd.DataFrame(big_actor_by_film.items(), columns = ['Film', 'Actor list'])
big_actor_by_film_df.head()
# Out:
#                              Film  \
# 0                  !Ay, mi madre!
# 1                    !Hay motivo!
# 2                  !Three Amigos!
# 3                          #Alive
# 4                         #Horror
# ...                           ...
# 41045                 s/y Gladjen
# 41046                      sxtape
# 41047                         xXx
# 41048  xXx: Return of Xander Cage
# 41049     xXx: State of the Union
#
#                                               Actor list
# 0                                             [Paz Vega]
# 1                              [Luis Tosar, Marta Etura]
# 2      [Steve Martin, Chevy Chase, Jon Lovitz, Joe Ma...
# 3                                        [Park Shin-Hye]
# 4      [Timothy Hutton, Balthazar Getty, Chloe Sevign...
# ...                                                  ...
# 41045                     [Lena Olin, Stellan Skarsgard]
# 41046                                        [Chris Coy]
# 41047  [Samuel L. Jackson, Asia Argento, Thomas Ian G...
# 41048  [Samuel L. Jackson, Toni Collette, Ice Cube, A...
# 41049  [Samuel L. Jackson, Willem Dafoe, Ice Cube, Sc...
#
# [41050 rows x 2 columns]

# %%
df = pd.merge(big_actor_by_film_df, poster, on="Film")
df = pd.merge(df, year_df, on="Film")
df.head()
# Out:
#            Film                                         Actor list  \
# 0        #Alive                                    [Park Shin-Hye]
# 1       #Horror  [Timothy Hutton, Balthazar Getty, Chloe Sevign...
# 2       #Horror  [Timothy Hutton, Balthazar Getty, Chloe Sevign...
# 3       #Horror  [Timothy Hutton, Balthazar Getty, Chloe Sevign...
# 4       #Horror  [Timothy Hutton, Balthazar Getty, Chloe Sevign...
# ...         ...                                                ...
# 89293  iMurders  [Gabrielle Anwar, Charles Durning, William For...
# 89294  iMurders  [Gabrielle Anwar, Charles Durning, William For...
# 89295  iMurders  [Gabrielle Anwar, Charles Durning, William For...
# 89296  iMurders  [Gabrielle Anwar, Charles Durning, William For...
# 89297    sxtape                                        [Chris Coy]
#
#                                                   poster  \
# 0      https://m.media-amazon.com/images/M/MV5BMGNiYj...
# 1      https://m.media-amazon.com/images/M/MV5BMjM5OD...
# 2      https://m.media-amazon.com/images/M/MV5BMjM5OD...
# 3      https://m.media-amazon.com/images/M/MV5BMjM5OD...
# 4      https://m.media-amazon.com/images/M/MV5BMjM5OD...
# ...                                                  ...
# 89293  https://m.media-amazon.com/images/M/MV5BMjE3ND...
# 89294  https://m.media-amazon.com/images/M/MV5BMjE3ND...
# 89295  https://m.media-amazon.com/images/M/MV5BMjE3ND...
# 89296  https://m.media-amazon.com/images/M/MV5BMjE3ND...
# 89297  https://m.media-amazon.com/images/M/MV5BNDU4MD...
#
#                        genre  Year
# 0      action, drama, horror  2020
# 1       crime, drama, horror  2015
# 2       crime, drama, horror  2015
# 3       crime, drama, horror  2015
# 4       crime, drama, horror  2015
# ...                      ...   ...
# 89293   crime, drama, horror  2008
# 89294   crime, drama, horror  2008
# 89295   crime, drama, horror  2008
# 89296   crime, drama, horror  2008
# 89297                 horror  2013
#
# [89298 rows x 5 columns]

# %%
df = df.drop_duplicates(subset=['Film'])
df = df.reset_index()
df.head()
# Out:
#        index          Film                                         Actor list  \
# 0          0        #Alive                                    [Park Shin-Hye]
# 1          1       #Horror  [Timothy Hutton, Balthazar Getty, Chloe Sevign...
# 2          7      #Iamhere                                        [Bae Doona]
# 3          8        #NAME?                   [Ray Milland, Robert Montgomery]
# 4         10  #REALITYHIGH  [Kate Walsh, John Michael Higgins, Anne Winter...
# ...      ...           ...                                                ...
# 11489  89284       [Rec] 2                                     [Javier Botet]
# 11490  89285        eCupid                                 [Morgan Fairchild]
# 11491  89286          iBoy  [Miranda Richardson, Rory Kinnear, Maisie Will...
# 11492  89290      iMurders  [Gabrielle Anwar, Charles Durning, William For...
# 11493  89297        sxtape                                        [Chris Coy]
#
#                                                   poster  \
# 0      https://m.media-amazon.com/images/M/MV5BMGNiYj...
# 1      https://m.media-amazon.com/images/M/MV5BMjM5OD...
# 2      https://m.media-amazon.com/images/M/MV5BZjRhN2...
# 3      https://m.media-amazon.com/images/M/MV5BNzdlZj...
# 4      https://m.media-amazon.com/images/M/MV5BNDU3Mz...
# ...                                                  ...
# 11489  https://m.media-amazon.com/images/M/MV5BMTI4Mj...
# 11490  https://m.media-amazon.com/images/M/MV5BMTQwMT...
# 11491  https://m.media-amazon.com/images/M/MV5BNjQxOD...
# 11492  https://m.media-amazon.com/images/M/MV5BMjE3ND...
# 11493  https://m.media-amazon.com/images/M/MV5BNDU4MD...
#
#                             genre  Year
# 0           action, drama, horror  2020
# 1            crime, drama, horror  2015
# 2                          comedy  2019
# 3        animation, short, comedy  1932
# 4          comedy, drama, romance  2017
# ...                           ...   ...
# 11489  action, adventure, fantasy  2009
# 11490                     romance  2011
# 11491       action, crime, sci-fi  2017
# 11492        crime, drama, horror  2008
# 11493                      horror  2013
#
# [11494 rows x 6 columns]

# %%
actors = np.unique(df['Actor list'])
genre = np.unique(df['genre'].str.split(', ').sum())
movie = np.unique(df['Film'].str.split(', ').sum())

# %%
combined_list = []

for lst in actors:
    combined_list.extend(lst)

unique_list = list(set(combined_list))

# %%
unique_list = np.array(unique_list)

# %%
unique_list
# Out:
# array(['Kyra Sedgwick', 'Bryan Singer', 'Nicole Maines', ...,
#        'Pamela Franklin', 'Paris Hilton', 'Lauren Miller Rogen'],
#       dtype='<U27')

# %%
df['Actor_List_id'] = df['Actor list'].apply(lambda x: [np.where(unique_list == i)[0][0] for i in x])

# %%
df.head()
# Out:
#    index          Film                                         Actor list  \
# 0      0        #Alive                                    [Park Shin-Hye]
# 1      1       #Horror  [Timothy Hutton, Balthazar Getty, Chloe Sevign...
# 2      7      #Iamhere                                        [Bae Doona]
# 3      8        #NAME?                   [Ray Milland, Robert Montgomery]
# 4     10  #REALITYHIGH  [Kate Walsh, John Michael Higgins, Anne Winter...
#
#                                               poster  \
# 0  https://m.media-amazon.com/images/M/MV5BMGNiYj...
# 1  https://m.media-amazon.com/images/M/MV5BMjM5OD...
# 2  https://m.media-amazon.com/images/M/MV5BZjRhN2...
# 3  https://m.media-amazon.com/images/M/MV5BNzdlZj...
# 4  https://m.media-amazon.com/images/M/MV5BNDU3Mz...
#
#                       genre  Year                         Actor_List_id
# 0     action, drama, horror  2020                                [3267]
# 1      crime, drama, horror  2015      [443, 3037, 5878, 2311, 7770, 6]
# 2                    comedy  2019                                [2192]
# 3  animation, short, comedy  1932                           [2888, 955]
# 4    comedy, drama, romance  2017  [1942, 7860, 2244, 7692, 2419, 6047]

# %%
adj_matrix = np.zeros((len(unique_list),len(unique_list)))

# %%
for i in range(len(df)):
    for j in range(len(df['Actor_List_id'][i])-1):
        for k in range(j+1,len(df['Actor_List_id'][i])-1):
            adj_matrix[df['Actor_List_id'][i][j]][df['Actor_List_id'][i][k]] = adj_matrix[df['Actor_List_id'][i][j]][df['Actor_List_id'][i][k]]+ 1
            adj_matrix[df['Actor_List_id'][i][k]][df['Actor_List_id'][i][j]] = adj_matrix[df['Actor_List_id'][i][k]][df['Actor_List_id'][i][j]]+ 1
